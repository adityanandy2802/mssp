# %%
import openpyxl
from openpyxl import Workbook
import pandas as pd
import numpy as np
from datetime import datetime

# %%
wb = openpyxl.load_workbook('template.xlsx')

# %%
year = "2022"
aco_list = ["Coastal Carolina Quality Care, Inc.", "Allcare Options, LLC", "ACO Health Partners, LLC"]

def exec(aco, year):
    data = pd.read_csv(f"PY_Financial_and_Quality_Results_{year}.csv")
    df = data[data["ACO_Name"] == aco].reset_index(inplace = False, drop=True)
    df = df.replace(r'\*', '0', regex=True)
    df = df.replace(r'\-', '0', regex = True)

    data_map = {}
    """Parameters"""
    sheet = "Cover"
    wb[sheet]["A13"] = f"{df.iloc[0]["ACO_ID"]}, {df.iloc[0]["ACO_Name"]}"
    wb[sheet]["A14"] = f"Financial Reconciliation Report, Performance Year {year}"
    def convert_date(date_str):
        date_string = "07/01/2019"
        input_format = "%m/%d/%Y"
        date_object = datetime.strptime(date_string, input_format)
        output_format = "%B %d, %Y"
        output_string = date_object.strftime(output_format)

        return output_string
    wb[sheet]["A16"] = f"{convert_date(df.iloc[0]["Current_Start_Date"])} Agreement Start Date"

    sheet = "Table 1 - Historical Benchmark"
    data_map[(sheet,"B10", int)] = "Per_Capita_Exp_ALL_ESRD_BY1"
    data_map[(sheet,"C10", int)] = "Per_Capita_Exp_ALL_ESRD_BY2"
    data_map[(sheet,"D10", int)] = "Per_Capita_Exp_ALL_ESRD_BY3"

    data_map[(sheet,"B11", int)] = "Per_Capita_Exp_ALL_DIS_BY1"
    data_map[(sheet,"C11", int)] = "Per_Capita_Exp_ALL_DIS_BY2"
    data_map[(sheet,"D11", int)] = "Per_Capita_Exp_ALL_DIS_BY3"

    data_map[(sheet,"B12", int)] = "Per_Capita_Exp_ALL_AGDU_BY1"
    data_map[(sheet,"C12", int)] = "Per_Capita_Exp_ALL_AGDU_BY2"
    data_map[(sheet,"D12", int)] = "Per_Capita_Exp_ALL_AGDU_BY3"

    data_map[(sheet,"B13", int)] = "Per_Capita_Exp_ALL_AGND_BY1"
    data_map[(sheet,"C13", int)] = "Per_Capita_Exp_ALL_AGND_BY2"
    data_map[(sheet,"D13", int)] = "Per_Capita_Exp_ALL_AGND_BY3"

    data_map[(sheet,"B15", float)] = "CMS_HCC_RiskScore_ESRD_BY1"
    data_map[(sheet,"C15", float)] = "CMS_HCC_RiskScore_ESRD_BY2"
    data_map[(sheet,"D15", float)] = "CMS_HCC_RiskScore_ESRD_BY3"

    data_map[(sheet,"B16", float)] = "CMS_HCC_RiskScore_DIS_BY1"
    data_map[(sheet,"C16", float)] = "CMS_HCC_RiskScore_DIS_BY2"
    data_map[(sheet,"D16", float)] = "CMS_HCC_RiskScore_DIS_BY3"

    data_map[(sheet,"B17", float)] = "CMS_HCC_RiskScore_AGDU_BY1"
    data_map[(sheet,"C17", float)] = "CMS_HCC_RiskScore_AGDU_BY2"
    data_map[(sheet,"D17", float)] = "CMS_HCC_RiskScore_AGDU_BY3"

    data_map[(sheet,"B18", float)] = "CMS_HCC_RiskScore_AGND_BY1"
    data_map[(sheet,"C18", float)] = "CMS_HCC_RiskScore_AGND_BY2"
    data_map[(sheet,"D18", float)] = "CMS_HCC_RiskScore_AGND_BY3"

    sheet = "Table 2 - Updated Benchmark"
    data_map[(sheet, "D13", float)] = "CMS_HCC_RiskScore_ESRD_PY"
    data_map[(sheet, "D14", float)] = "CMS_HCC_RiskScore_DIS_PY"
    data_map[(sheet, "D15", float)] = "CMS_HCC_RiskScore_AGDU_PY"
    data_map[(sheet, "D16", float)] = "CMS_HCC_RiskScore_AGND_PY"

    sheet = "Table 3 - Shared Savings Losses"
    data_map[(sheet, "B6", int)] = "N_AB"
    data_map[(sheet, "B7", int)] = "N_AB_Year_PY"
    data_map[(sheet, "B9", int)] = "Per_Capita_Exp_ALL_ESRD_PY"
    data_map[(sheet, "B10", int)] = "Per_Capita_Exp_ALL_DIS_PY"
    data_map[(sheet, "B11", int)] = "Per_Capita_Exp_ALL_AGDU_PY"
    data_map[(sheet, "B12", int)] = "Per_Capita_Exp_ALL_AGND_PY"
    data_map[(sheet, "B25", str)] = "MinSavPerc"
    data_map[(sheet, "B32", str)] = "QualScore"
    data_map[(sheet, "B34", str)] = "FinalShareRate"

    sheet = "Table 1 - Historical Benchmark"
    s = 0
    for i in ["ESRD", "DIS", "AGED_Dual", "AGED_NonDual"]:
        s += float(df.iloc[0][f"N_AB_Year_{i}_BY3"])
    wb[sheet]["D40"] = float(df.iloc[0]["N_AB_Year_ESRD_BY3"]) / s
    wb[sheet]["D41"] = float(df.iloc[0]["N_AB_Year_DIS_BY3"]) / s
    wb[sheet]["D42"] = float(df.iloc[0]["N_AB_Year_AGED_Dual_BY3"]) / s
    wb[sheet]["D43"] = float(df.iloc[0]["N_AB_Year_AGED_NonDual_BY3"]) / s

    sheet = "Table 2 - Updated Benchmark"
    s = 0
    for i in ["ESRD", "DIS", "AGED_Dual", "AGED_NonDual"]:
        s += float(df.iloc[0][f"N_AB_Year_{i}_PY"])
    wb[sheet]["D38"] = float(df.iloc[0]["N_AB_Year_ESRD_PY"]) / s
    wb[sheet]["D39"] = float(df.iloc[0]["N_AB_Year_DIS_PY"]) / s
    wb[sheet]["D40"] = float(df.iloc[0]["N_AB_Year_AGED_Dual_PY"]) / s
    wb[sheet]["D41"] = float(df.iloc[0]["N_AB_Year_AGED_NonDual_PY"]) / s

    for key in data_map.keys():
        ws = wb[key[0]]
        ws[key[1]] = key[2](df.iloc[0][f"{data_map[(key)]}"])

    wb.save(f"template_res_{aco}_{year}.xlsx")

def print_info(aco, year):
    data = pd.read_csv(f"PY_Financial_and_Quality_Results_{year}.csv")
    df = data[data["ACO_Name"] == aco].reset_index(inplace = False, drop=True)
    df = df.replace(r'\*', '0', regex=True)
    df = df.replace(r'\-', '0', regex = True)
    for col in df.columns:
        print(f"{col}                          {df.iloc[0][col]}")
    return

# %%
for aco in aco_list:
    exec(aco, year)
    print_info(aco, year)
# Out:
# ACO_ID                          A1051
# ACO_Name                          Coastal Carolina Quality Care, Inc.
# Agree_Type                          Renewal
# Agreement_Period_Num                          3
# Current_Start_Date                          07/01/2019
# Current_Track                          EN
# Risk_Model                          Two0Sided
# Assign_Type                          Prospective
# SNF_Waiver                          0
# N_AB                          11049
# Sav_rate                          13.74%
# MinSavPerc                          1.00%
# BnchmkMinExp                          16705344
# GenSaveLoss                          16705344
# DisAdj                          nan
# Impact_Mid_Year_Termination                          0
# EarnSaveLoss                          12278428
# DisAffQual                          1
# Met_QPS                          1
# Met_30pctl                          1
# Met_Incentive                          0
# Met_FirstYear                          0
# Report_WI                          1
# Report_eCQM_CQM                          0
# Report_Inc                          0
# QualScore                          90.15%
# Recvd30p                          0
# PosRegAdj                          148
# UpdatedBnchmk                          11242
# HistBnchmk                          10393
# ABtotBnchmk                          121589728
# ABtotExp                          104884384
# FinalShareRate                          75.00%
# Rev_Exp_Cat                          Low Revenue
# Per_Capita_Exp_ALL_ESRD_BY1                          70892
# Per_Capita_Exp_ALL_DIS_BY1                          10225
# Per_Capita_Exp_ALL_AGDU_BY1                          12916
# Per_Capita_Exp_ALL_AGND_BY1                          8999
# Per_Capita_Exp_ALL_ESRD_BY2                          76104
# Per_Capita_Exp_ALL_DIS_BY2                          9058
# Per_Capita_Exp_ALL_AGDU_BY2                          13020
# Per_Capita_Exp_ALL_AGND_BY2                          8880
# Per_Capita_Exp_ALL_ESRD_BY3                          73867
# Per_Capita_Exp_ALL_DIS_BY3                          10263
# Per_Capita_Exp_ALL_AGDU_BY3                          14943
# Per_Capita_Exp_ALL_AGND_BY3                          9371
# Per_Capita_Exp_ALL_ESRD_PY                          0
# Per_Capita_Exp_ALL_DIS_PY                          9984
# Per_Capita_Exp_ALL_AGDU_PY                          16259
# Per_Capita_Exp_ALL_AGND_PY                          9459
# Per_Capita_Exp_TOTAL_PY                          9697
# CMS_HCC_RiskScore_ESRD_BY1                          1.009
# CMS_HCC_RiskScore_DIS_BY1                          1.162
# CMS_HCC_RiskScore_AGDU_BY1                          1.132
# CMS_HCC_RiskScore_AGND_BY1                          1.083
# CMS_HCC_RiskScore_ESRD_BY2                          1.023
# CMS_HCC_RiskScore_DIS_BY2                          1.033
# CMS_HCC_RiskScore_AGDU_BY2                          1.048
# CMS_HCC_RiskScore_AGND_BY2                          1.037
# CMS_HCC_RiskScore_ESRD_BY3                          1.041
# CMS_HCC_RiskScore_DIS_BY3                          1.146
# CMS_HCC_RiskScore_AGDU_BY3                          1.161
# CMS_HCC_RiskScore_AGND_BY3                          1.181
# CMS_HCC_RiskScore_ESRD_PY                          0
# CMS_HCC_RiskScore_DIS_PY                          1.204
# CMS_HCC_RiskScore_AGDU_PY                          1.27
# CMS_HCC_RiskScore_AGND_PY                          1.242
# N_AB_Year_ESRD_BY3                          22
# N_AB_Year_DIS_BY3                          805
# N_AB_Year_AGED_Dual_BY3                          435
# N_AB_Year_AGED_NonDual_BY3                          10004
# N_AB_Year_PY                          10816
# N_AB_Year_ESRD_PY                          0
# N_AB_Year_DIS_PY                          523
# N_AB_Year_AGED_Dual_PY                          0
# N_AB_Year_AGED_NonDual_PY                          10011
# N_Ben_VA_Only                          0
# N_Ben_CBA_Only                          10968
# N_Ben_CBA_and_VA                          0
# N_Ben_Age_0_64                          552
# N_Ben_Age_65_74                          5257
# N_Ben_Age_75_84                          3908
# N_Ben_Age_85plus                          1332
# N_Ben_Female                          6143
# N_Ben_Male                          4906
# N_Ben_Race_White                          9647
# N_Ben_Race_Black                          1082
# N_Ben_Race_Asian                          34
# N_Ben_Race_Hisp                          0
# N_Ben_Race_Native                          0
# N_Ben_Race_Other                          49
# N_Ben_Race_Unknown                          220
# CapAnn_INP_All                          2295
# CapAnn_INP_S_trm                          2126
# CapAnn_INP_L_trm                          0
# CapAnn_INP_Rehab                          136
# CapAnn_INP_Psych                          0
# CapAnn_HSP                          313
# CapAnn_SNF                          343
# CapAnn_OPD                          2346
# CapAnn_PB                          3922
# CapAnn_AmbPay                          74
# CapAnn_HHA                          301
# CapAnn_DME                          238
# ADM                          193
# ADM_S_Trm                          184
# ADM_L_Trm                          0
# ADM_Rehab                          8
# ADM_Psych                          0
# P_EDV_Vis                          447
# P_EDV_Vis_HOSP                          148
# P_CT_VIS                          840
# P_MRI_VIS                          260
# P_EM_Total                          11681
# P_EM_PCP_Vis                          4647
# P_EM_SP_Vis                          4090
# P_Nurse_Vis                          2917
# P_FQHC_RHC_Vis                          28
# P_SNF_ADM                          29
# SNF_LOS                          27
# SNF_PayperStay                          11356
# N_CAH                          0
# N_FQHC                          0
# N_RHC                          0
# N_ETA                          0
# N_Hosp                          0
# N_Fac_Other                          0
# N_PCP                          39
# N_Spec                          68
# N_NP                          39
# N_PA                          40
# N_CNS                          0
# Perc_Dual                          4.09%
# Perc_CovDiag                          16.84%
# Perc_CovEpisode                          1.57%
# Perc_LTI                          1.19%
# CAHPS_1                          84.77
# CAHPS_2                          93.16
# CAHPS_3                          91.8
# CAHPS_4                          73.7
# CAHPS_5                          68.62
# CAHPS_6                          62.91
# CAHPS_7                          76.42
# CAHPS_11                          34.29
# CAHPS_9                          93.08
# CAHPS_8                          86.57
# Measure_479                          0.1619
# Measure_484                          23.32
# QualityID_318                          94.85
# QualityID_110                          87.8
# QualityID_226                          92.31
# QualityID_134_WI                          95.55
# QualityID_134_eCQM                          0
# QualityID_134_MIPSCQM                          0
# QualityID_113                          93.63
# QualityID_112                          94.36
# QualityID_438                          92.89
# QualityID_370                          2.78
# QualityID_001_WI                          4.17
# QualityID_001_eCQM                          0
# QualityID_001_MIPSCQM                          0
# QualityID_236_WI                          88.25
# QualityID_236_eCQM                          0
# QualityID_236_MIPSCQM                          0
# ACO_ID                          A1070
# ACO_Name                          Allcare Options, LLC
# Agree_Type                          Renewal
# Agreement_Period_Num                          3
# Current_Start_Date                          07/01/2019
# Current_Track                          D
# Risk_Model                          Two0Sided
# Assign_Type                          Retrospective
# SNF_Waiver                          0
# N_AB                          22904
# Sav_rate                          05.15%
# MinSavPerc                          2.47%
# BnchmkMinExp                          -28610637
# GenSaveLoss                          -28610637
# DisAdj                          -2320475.0
# Impact_Mid_Year_Termination                          0
# EarnSaveLoss                          0
# DisAffQual                          1
# Met_QPS                          1
# Met_30pctl                          1
# Met_Incentive                          0
# Met_FirstYear                          0
# Report_WI                          1
# Report_eCQM_CQM                          0
# Report_Inc                          0
# QualScore                          70.63%
# Recvd30p                          1
# PosRegAdj                          -613
# UpdatedBnchmk                          26662
# HistBnchmk                          23904
# ABtotBnchmk                          555253455
# ABtotExp                          583864092
# FinalShareRate                          50.00%
# Rev_Exp_Cat                          Low Revenue
# Per_Capita_Exp_ALL_ESRD_BY1                          119476
# Per_Capita_Exp_ALL_DIS_BY1                          16674
# Per_Capita_Exp_ALL_AGDU_BY1                          27067
# Per_Capita_Exp_ALL_AGND_BY1                          24374
# Per_Capita_Exp_ALL_ESRD_BY2                          113276
# Per_Capita_Exp_ALL_DIS_BY2                          15867
# Per_Capita_Exp_ALL_AGDU_BY2                          27185
# Per_Capita_Exp_ALL_AGND_BY2                          23501
# Per_Capita_Exp_ALL_ESRD_BY3                          110701
# Per_Capita_Exp_ALL_DIS_BY3                          14460
# Per_Capita_Exp_ALL_AGDU_BY3                          25299
# Per_Capita_Exp_ALL_AGND_BY3                          21930
# Per_Capita_Exp_ALL_ESRD_PY                          111955
# Per_Capita_Exp_ALL_DIS_PY                          20938
# Per_Capita_Exp_ALL_AGDU_PY                          32225
# Per_Capita_Exp_ALL_AGND_PY                          24840
# Per_Capita_Exp_TOTAL_PY                          28036
# CMS_HCC_RiskScore_ESRD_BY1                          1.144
# CMS_HCC_RiskScore_DIS_BY1                          1.223
# CMS_HCC_RiskScore_AGDU_BY1                          1.267
# CMS_HCC_RiskScore_AGND_BY1                          1.337
# CMS_HCC_RiskScore_ESRD_BY2                          1.137
# CMS_HCC_RiskScore_DIS_BY2                          1.166
# CMS_HCC_RiskScore_AGDU_BY2                          1.169
# CMS_HCC_RiskScore_AGND_BY2                          1.294
# CMS_HCC_RiskScore_ESRD_BY3                          1.138
# CMS_HCC_RiskScore_DIS_BY3                          1.1
# CMS_HCC_RiskScore_AGDU_BY3                          1.168
# CMS_HCC_RiskScore_AGND_BY3                          1.275
# CMS_HCC_RiskScore_ESRD_PY                          1.113
# CMS_HCC_RiskScore_DIS_PY                          1.286
# CMS_HCC_RiskScore_AGDU_PY                          1.282
# CMS_HCC_RiskScore_AGND_PY                          1.314
# N_AB_Year_ESRD_BY3                          367
# N_AB_Year_DIS_BY3                          4014
# N_AB_Year_AGED_Dual_BY3                          5612
# N_AB_Year_AGED_NonDual_BY3                          7663
# N_AB_Year_PY                          20825
# N_AB_Year_ESRD_PY                          226
# N_AB_Year_DIS_PY                          3232
# N_AB_Year_AGED_Dual_PY                          8052
# N_AB_Year_AGED_NonDual_PY                          9315
# N_Ben_VA_Only                          0
# N_Ben_CBA_Only                          22876
# N_Ben_CBA_and_VA                          0
# N_Ben_Age_0_64                          4027
# N_Ben_Age_65_74                          7317
# N_Ben_Age_75_84                          6448
# N_Ben_Age_85plus                          5112
# N_Ben_Female                          13648
# N_Ben_Male                          9256
# N_Ben_Race_White                          17679
# N_Ben_Race_Black                          3584
# N_Ben_Race_Asian                          167
# N_Ben_Race_Hisp                          860
# N_Ben_Race_Native                          29
# N_Ben_Race_Other                          224
# N_Ben_Race_Unknown                          361
# CapAnn_INP_All                          7119
# CapAnn_INP_S_trm                          6027
# CapAnn_INP_L_trm                          406
# CapAnn_INP_Rehab                          565
# CapAnn_INP_Psych                          229
# CapAnn_HSP                          2659
# CapAnn_SNF                          7739
# CapAnn_OPD                          4385
# CapAnn_PB                          5482
# CapAnn_AmbPay                          436
# CapAnn_HHA                          983
# CapAnn_DME                          381
# ADM                          713
# ADM_S_Trm                          657
# ADM_L_Trm                          9
# ADM_Rehab                          28
# ADM_Psych                          19
# P_EDV_Vis                          1324
# P_EDV_Vis_HOSP                          622
# P_CT_VIS                          1206
# P_MRI_VIS                          169
# P_EM_Total                          26445
# P_EM_PCP_Vis                          5032
# P_EM_SP_Vis                          4640
# P_Nurse_Vis                          7607
# P_FQHC_RHC_Vis                          9166
# P_SNF_ADM                          495
# SNF_LOS                          31
# SNF_PayperStay                          14202
# N_CAH                          0
# N_FQHC                          113
# N_RHC                          0
# N_ETA                          0
# N_Hosp                          0
# N_Fac_Other                          0
# N_PCP                          182
# N_Spec                          122
# N_NP                          431
# N_PA                          46
# N_CNS                          1
# Perc_Dual                          51.30%
# Perc_CovDiag                          29.05%
# Perc_CovEpisode                          5.57%
# Perc_LTI                          39.08%
# CAHPS_1                          86.61
# CAHPS_2                          94.56
# CAHPS_3                          92.55
# CAHPS_4                          79.95
# CAHPS_5                          66.84
# CAHPS_6                          60.59
# CAHPS_7                          70.96
# CAHPS_11                          29.01
# CAHPS_9                          93.14
# CAHPS_8                          86.73
# Measure_479                          0.1552
# Measure_484                          34.74
# QualityID_318                          44.55
# QualityID_110                          37.7
# QualityID_226                          89.66
# QualityID_134_WI                          40.2
# QualityID_134_eCQM                          0
# QualityID_134_MIPSCQM                          0
# QualityID_113                          39.84
# QualityID_112                          52.87
# QualityID_438                          75.2
# QualityID_370                          10
# QualityID_001_WI                          24.13
# QualityID_001_eCQM                          0
# QualityID_001_MIPSCQM                          0
# QualityID_236_WI                          61.5
# QualityID_236_eCQM                          0
# QualityID_236_MIPSCQM                          0
# ACO_ID                          A1540
# ACO_Name                          ACO Health Partners, LLC
# Agree_Type                          Renewal
# Agreement_Period_Num                          3
# Current_Start_Date                          07/01/2019
# Current_Track                          B
# Risk_Model                          One0Sided
# Assign_Type                          Retrospective
# SNF_Waiver                          0
# N_AB                          7207
# Sav_rate                          7.43%
# MinSavPerc                          3.36%
# BnchmkMinExp                          7354963
# GenSaveLoss                          7354963
# DisAdj                          nan
# Impact_Mid_Year_Termination                          0
# EarnSaveLoss                          2883146
# DisAffQual                          1
# Met_QPS                          1
# Met_30pctl                          1
# Met_Incentive                          0
# Met_FirstYear                          0
# Report_WI                          1
# Report_eCQM_CQM                          0
# Report_Inc                          0
# QualScore                          73.26%
# Recvd30p                          0
# PosRegAdj                          78
# UpdatedBnchmk                          14137
# HistBnchmk                          13831
# ABtotBnchmk                          98947417
# ABtotExp                          91592454
# FinalShareRate                          40.00%
# Rev_Exp_Cat                          Low Revenue
# Per_Capita_Exp_ALL_ESRD_BY1                          99815
# Per_Capita_Exp_ALL_DIS_BY1                          12065
# Per_Capita_Exp_ALL_AGDU_BY1                          18061
# Per_Capita_Exp_ALL_AGND_BY1                          11341
# Per_Capita_Exp_ALL_ESRD_BY2                          96209
# Per_Capita_Exp_ALL_DIS_BY2                          11790
# Per_Capita_Exp_ALL_AGDU_BY2                          17913
# Per_Capita_Exp_ALL_AGND_BY2                          11731
# Per_Capita_Exp_ALL_ESRD_BY3                          98987
# Per_Capita_Exp_ALL_DIS_BY3                          12342
# Per_Capita_Exp_ALL_AGDU_BY3                          19814
# Per_Capita_Exp_ALL_AGND_BY3                          12174
# Per_Capita_Exp_ALL_ESRD_PY                          71529
# Per_Capita_Exp_ALL_DIS_PY                          11771
# Per_Capita_Exp_ALL_AGDU_PY                          20193
# Per_Capita_Exp_ALL_AGND_PY                          12315
# Per_Capita_Exp_TOTAL_PY                          13086
# CMS_HCC_RiskScore_ESRD_BY1                          1.08
# CMS_HCC_RiskScore_DIS_BY1                          1.107
# CMS_HCC_RiskScore_AGDU_BY1                          1.155
# CMS_HCC_RiskScore_AGND_BY1                          1.16
# CMS_HCC_RiskScore_ESRD_BY2                          1.093
# CMS_HCC_RiskScore_DIS_BY2                          1.089
# CMS_HCC_RiskScore_AGDU_BY2                          1.128
# CMS_HCC_RiskScore_AGND_BY2                          1.155
# CMS_HCC_RiskScore_ESRD_BY3                          1.065
# CMS_HCC_RiskScore_DIS_BY3                          1.111
# CMS_HCC_RiskScore_AGDU_BY3                          1.122
# CMS_HCC_RiskScore_AGND_BY3                          1.148
# CMS_HCC_RiskScore_ESRD_PY                          1.012
# CMS_HCC_RiskScore_DIS_PY                          1.108
# CMS_HCC_RiskScore_AGDU_PY                          1.115
# CMS_HCC_RiskScore_AGND_PY                          1.205
# N_AB_Year_ESRD_BY3                          92
# N_AB_Year_DIS_BY3                          1514
# N_AB_Year_AGED_Dual_BY3                          790
# N_AB_Year_AGED_NonDual_BY3                          6174
# N_AB_Year_PY                          6999
# N_AB_Year_ESRD_PY                          24
# N_AB_Year_DIS_PY                          887
# N_AB_Year_AGED_Dual_PY                          568
# N_AB_Year_AGED_NonDual_PY                          5520
# N_Ben_VA_Only                          13
# N_Ben_CBA_Only                          7171
# N_Ben_CBA_and_VA                          23
# N_Ben_Age_0_64                          1112
# N_Ben_Age_65_74                          3387
# N_Ben_Age_75_84                          2049
# N_Ben_Age_85plus                          659
# N_Ben_Female                          4068
# N_Ben_Male                          3139
# N_Ben_Race_White                          6151
# N_Ben_Race_Black                          534
# N_Ben_Race_Asian                          179
# N_Ben_Race_Hisp                          0
# N_Ben_Race_Native                          0
# N_Ben_Race_Other                          120
# N_Ben_Race_Unknown                          116
# CapAnn_INP_All                          3455
# CapAnn_INP_S_trm                          3079
# CapAnn_INP_L_trm                          52
# CapAnn_INP_Rehab                          281
# CapAnn_INP_Psych                          49
# CapAnn_HSP                          337
# CapAnn_SNF                          1039
# CapAnn_OPD                          2150
# CapAnn_PB                          5156
# CapAnn_AmbPay                          92
# CapAnn_HHA                          593
# CapAnn_DME                          386
# ADM                          322
# ADM_S_Trm                          303
# ADM_L_Trm                          2
# ADM_Rehab                          13
# ADM_Psych                          5
# P_EDV_Vis                          710
# P_EDV_Vis_HOSP                          264
# P_CT_VIS                          937
# P_MRI_VIS                          338
# P_EM_Total                          13915
# P_EM_PCP_Vis                          6028
# P_EM_SP_Vis                          5801
# P_Nurse_Vis                          2063
# P_FQHC_RHC_Vis                          23
# P_SNF_ADM                          66
# SNF_LOS                          25
# SNF_PayperStay                          13847
# N_CAH                          0
# N_FQHC                          0
# N_RHC                          0
# N_ETA                          0
# N_Hosp                          0
# N_Fac_Other                          0
# N_PCP                          58
# N_Spec                          72
# N_NP                          111
# N_PA                          29
# N_CNS                          0
# Perc_Dual                          14.38%
# Perc_CovDiag                          18.75%
# Perc_CovEpisode                          2.47%
# Perc_LTI                          2.97%
# CAHPS_1                          81.42
# CAHPS_2                          92.49
# CAHPS_3                          91.61
# CAHPS_4                          76.46
# CAHPS_5                          61.72
# CAHPS_6                          65.34
# CAHPS_7                          70.77
# CAHPS_11                          20.21
# CAHPS_9                          89.66
# CAHPS_8                          85.2
# Measure_479                          0.1637
# Measure_484                          32.39
# QualityID_318                          74.66
# QualityID_110                          60.84
# QualityID_226                          90.62
# QualityID_134_WI                          73.28
# QualityID_134_eCQM                          0
# QualityID_134_MIPSCQM                          0
# QualityID_113                          60.08
# QualityID_112                          76.16
# QualityID_438                          86.13
# QualityID_370                          13.33
# QualityID_001_WI                          20.16
# QualityID_001_eCQM                          0
# QualityID_001_MIPSCQM                          0
# QualityID_236_WI                          84.58
# QualityID_236_eCQM                          0
# QualityID_236_MIPSCQM                          0

# %%
# Out:
# ACO_ID                          A1051
# ACO_Name                          Coastal Carolina Quality Care, Inc.
# Agree_Type                          Renewal
# Agreement_Period_Num                          3
# Current_Start_Date                          07/01/2019
# Current_Track                          EN
# Risk_Model                          Two0Sided
# Assign_Type                          Prospective
# SNF_Waiver                          0
# N_AB                          11049
# Sav_rate                          13.74%
# MinSavPerc                          1.00%
# BnchmkMinExp                          16705344
# GenSaveLoss                          16705344
# DisAdj                          nan
# Impact_Mid_Year_Termination                          0
# EarnSaveLoss                          12278428
# DisAffQual                          1
# Met_QPS                          1
# Met_30pctl                          1
# Met_Incentive                          0
# Met_FirstYear                          0
# Report_WI                          1
# Report_eCQM_CQM                          0
# Report_Inc                          0
# QualScore                          90.15%
# Recvd30p                          0
# PosRegAdj                          148
# UpdatedBnchmk                          11242
# HistBnchmk                          10393
# ABtotBnchmk                          121589728
# ABtotExp                          104884384
# FinalShareRate                          75.00%
# Rev_Exp_Cat                          Low Revenue
# Per_Capita_Exp_ALL_ESRD_BY1                          70892
# Per_Capita_Exp_ALL_DIS_BY1                          10225
# Per_Capita_Exp_ALL_AGDU_BY1                          12916
# Per_Capita_Exp_ALL_AGND_BY1                          8999
# Per_Capita_Exp_ALL_ESRD_BY2                          76104
# Per_Capita_Exp_ALL_DIS_BY2                          9058
# Per_Capita_Exp_ALL_AGDU_BY2                          13020
# Per_Capita_Exp_ALL_AGND_BY2                          8880
# Per_Capita_Exp_ALL_ESRD_BY3                          73867
# Per_Capita_Exp_ALL_DIS_BY3                          10263
# Per_Capita_Exp_ALL_AGDU_BY3                          14943
# Per_Capita_Exp_ALL_AGND_BY3                          9371
# Per_Capita_Exp_ALL_ESRD_PY                          0
# Per_Capita_Exp_ALL_DIS_PY                          9984
# Per_Capita_Exp_ALL_AGDU_PY                          16259
# Per_Capita_Exp_ALL_AGND_PY                          9459
# Per_Capita_Exp_TOTAL_PY                          9697
# CMS_HCC_RiskScore_ESRD_BY1                          1.009
# CMS_HCC_RiskScore_DIS_BY1                          1.162
# CMS_HCC_RiskScore_AGDU_BY1                          1.132
# CMS_HCC_RiskScore_AGND_BY1                          1.083
# CMS_HCC_RiskScore_ESRD_BY2                          1.023
# CMS_HCC_RiskScore_DIS_BY2                          1.033
# CMS_HCC_RiskScore_AGDU_BY2                          1.048
# CMS_HCC_RiskScore_AGND_BY2                          1.037
# CMS_HCC_RiskScore_ESRD_BY3                          1.041
# CMS_HCC_RiskScore_DIS_BY3                          1.146
# CMS_HCC_RiskScore_AGDU_BY3                          1.161
# CMS_HCC_RiskScore_AGND_BY3                          1.181
# CMS_HCC_RiskScore_ESRD_PY                          0
# CMS_HCC_RiskScore_DIS_PY                          1.204
# CMS_HCC_RiskScore_AGDU_PY                          1.27
# CMS_HCC_RiskScore_AGND_PY                          1.242
# N_AB_Year_ESRD_BY3                          22
# N_AB_Year_DIS_BY3                          805
# N_AB_Year_AGED_Dual_BY3                          435
# N_AB_Year_AGED_NonDual_BY3                          10004
# N_AB_Year_PY                          10816
# N_AB_Year_ESRD_PY                          0
# N_AB_Year_DIS_PY                          523
# N_AB_Year_AGED_Dual_PY                          0
# N_AB_Year_AGED_NonDual_PY                          10011
# N_Ben_VA_Only                          0
# N_Ben_CBA_Only                          10968
# N_Ben_CBA_and_VA                          0
# N_Ben_Age_0_64                          552
# N_Ben_Age_65_74                          5257
# N_Ben_Age_75_84                          3908
# N_Ben_Age_85plus                          1332
# N_Ben_Female                          6143
# N_Ben_Male                          4906
# N_Ben_Race_White                          9647
# N_Ben_Race_Black                          1082
# N_Ben_Race_Asian                          34
# N_Ben_Race_Hisp                          0
# N_Ben_Race_Native                          0
# N_Ben_Race_Other                          49
# N_Ben_Race_Unknown                          220
# CapAnn_INP_All                          2295
# CapAnn_INP_S_trm                          2126
# CapAnn_INP_L_trm                          0
# CapAnn_INP_Rehab                          136
# CapAnn_INP_Psych                          0
# CapAnn_HSP                          313
# CapAnn_SNF                          343
# CapAnn_OPD                          2346
# CapAnn_PB                          3922
# CapAnn_AmbPay                          74
# CapAnn_HHA                          301
# CapAnn_DME                          238
# ADM                          193
# ADM_S_Trm                          184
# ADM_L_Trm                          0
# ADM_Rehab                          8
# ADM_Psych                          0
# P_EDV_Vis                          447
# P_EDV_Vis_HOSP                          148
# P_CT_VIS                          840
# P_MRI_VIS                          260
# P_EM_Total                          11681
# P_EM_PCP_Vis                          4647
# P_EM_SP_Vis                          4090
# P_Nurse_Vis                          2917
# P_FQHC_RHC_Vis                          28
# P_SNF_ADM                          29
# SNF_LOS                          27
# SNF_PayperStay                          11356
# N_CAH                          0
# N_FQHC                          0
# N_RHC                          0
# N_ETA                          0
# N_Hosp                          0
# N_Fac_Other                          0
# N_PCP                          39
# N_Spec                          68
# N_NP                          39
# N_PA                          40
# N_CNS                          0
# Perc_Dual                          4.09%
# Perc_CovDiag                          16.84%
# Perc_CovEpisode                          1.57%
# Perc_LTI                          1.19%
# CAHPS_1                          84.77
# CAHPS_2                          93.16
# CAHPS_3                          91.8
# CAHPS_4                          73.7
# CAHPS_5                          68.62
# CAHPS_6                          62.91
# CAHPS_7                          76.42
# CAHPS_11                          34.29
# CAHPS_9                          93.08
# CAHPS_8                          86.57
# Measure_479                          0.1619
# Measure_484                          23.32
# QualityID_318                          94.85
# QualityID_110                          87.8
# QualityID_226                          92.31
# QualityID_134_WI                          95.55
# QualityID_134_eCQM                          0
# QualityID_134_MIPSCQM                          0
# QualityID_113                          93.63
# QualityID_112                          94.36
# QualityID_438                          92.89
# QualityID_370                          2.78
# QualityID_001_WI                          4.17
# QualityID_001_eCQM                          0
# QualityID_001_MIPSCQM                          0
# QualityID_236_WI                          88.25
# QualityID_236_eCQM                          0
# QualityID_236_MIPSCQM                          0

# %%
list(data.columns)
# Out:
# ['ACO_ID',
#  'ACO_Name',
#  'Agree_Type',
#  'Agreement_Period_Num',
#  'Current_Start_Date',
#  'Current_Track',
#  'Risk_Model',
#  'Assign_Type',
#  'SNF_Waiver',
#  'N_AB',
#  'Sav_rate',
#  'MinSavPerc',
#  'BnchmkMinExp',
#  'GenSaveLoss',
#  'DisAdj',
#  'Impact_Mid_Year_Termination',
#  'EarnSaveLoss',
#  'DisAffQual',
#  'Met_QPS',
#  'Met_AltQPS',
#  'Met_30pctl',
#  'Met_Incentive',
#  'Met_FirstYear',
#  'Report_WI',
#  'Report_eCQM_CQM',
#  'Report_Inc',
#  'QualScore',
#  'Recvd30p',
#  'PosRegAdj',
#  'UpdatedBnchmk',
#  'HistBnchmk',
#  'ABtotBnchmk',
#  'ABtotExp',
#  'FinalShareRate',
#  'FinalLossRate',
#  'Rev_Exp_Cat',
#  'Per_Capita_Exp_ALL_ESRD_BY1',
#  'Per_Capita_Exp_ALL_DIS_BY1',
#  'Per_Capita_Exp_ALL_AGDU_BY1',
#  'Per_Capita_Exp_ALL_AGND_BY1',
#  'Per_Capita_Exp_ALL_ESRD_BY2',
#  'Per_Capita_Exp_ALL_DIS_BY2',
#  'Per_Capita_Exp_ALL_AGDU_BY2',
#  'Per_Capita_Exp_ALL_AGND_BY2',
#  'Per_Capita_Exp_ALL_ESRD_BY3',
#  'Per_Capita_Exp_ALL_DIS_BY3',
#  'Per_Capita_Exp_ALL_AGDU_BY3',
#  'Per_Capita_Exp_ALL_AGND_BY3',
#  'Per_Capita_Exp_ALL_ESRD_PY',
#  'Per_Capita_Exp_ALL_DIS_PY',
#  'Per_Capita_Exp_ALL_AGDU_PY',
#  'Per_Capita_Exp_ALL_AGND_PY',
#  'Per_Capita_Exp_TOTAL_PY',
#  'CMS_HCC_RiskScore_ESRD_BY1',
#  'CMS_HCC_RiskScore_DIS_BY1',
#  'CMS_HCC_RiskScore_AGDU_BY1',
#  'CMS_HCC_RiskScore_AGND_BY1',
#  'CMS_HCC_RiskScore_ESRD_BY2',
#  'CMS_HCC_RiskScore_DIS_BY2',
#  'CMS_HCC_RiskScore_AGDU_BY2',
#  'CMS_HCC_RiskScore_AGND_BY2',
#  'CMS_HCC_RiskScore_ESRD_BY3',
#  'CMS_HCC_RiskScore_DIS_BY3',
#  'CMS_HCC_RiskScore_AGDU_BY3',
#  'CMS_HCC_RiskScore_AGND_BY3',
#  'CMS_HCC_RiskScore_ESRD_PY',
#  'CMS_HCC_RiskScore_DIS_PY',
#  'CMS_HCC_RiskScore_AGDU_PY',
#  'CMS_HCC_RiskScore_AGND_PY',
#  'N_AB_Year_ESRD_BY3',
#  'N_AB_Year_DIS_BY3',
#  'N_AB_Year_AGED_Dual_BY3',
#  'N_AB_Year_AGED_NonDual_BY3',
#  'N_AB_Year_PY',
#  'N_AB_Year_ESRD_PY',
#  'N_AB_Year_DIS_PY',
#  'N_AB_Year_AGED_Dual_PY',
#  'N_AB_Year_AGED_NonDual_PY',
#  'N_AB_Year_Dual_PY',
#  'N_AB_Year_NonDual_PY',
#  'N_Ben_VA_Only',
#  'N_Ben_CBA_Only',
#  'N_Ben_CBA_and_VA',
#  'N_Ben_Age_0_64',
#  'N_Ben_Age_65_74',
#  'N_Ben_Age_75_84',
#  'N_Ben_Age_85plus',
#  'N_Ben_Female',
#  'N_Ben_Male',
#  'N_Ben_Race_White',
#  'N_Ben_Race_Black',
#  'N_Ben_Race_Asian',
#  'N_Ben_Race_Hisp',
#  'N_Ben_Race_Native',
#  'N_Ben_Race_Other',
#  'N_Ben_Race_Unknown',
#  'CapAnn_INP_All',
#  'CapAnn_INP_S_trm',
#  'CapAnn_INP_L_trm',
#  'CapAnn_INP_Rehab',
#  'CapAnn_INP_Psych',
#  'CapAnn_HSP',
#  'CapAnn_SNF',
#  'CapAnn_OPD',
#  'CapAnn_PB',
#  'CapAnn_AmbPay',
#  'CapAnn_HHA',
#  'CapAnn_DME',
#  'ADM',
#  'ADM_S_Trm',
#  'ADM_L_Trm',
#  'ADM_Rehab',
#  'ADM_Psych',
#  'P_EDV_Vis',
#  'P_EDV_Vis_HOSP',
#  'P_CT_VIS',
#  'P_MRI_VIS',
#  'P_EM_Total',
#  'P_EM_PCP_Vis',
#  'P_EM_SP_Vis',
#  'P_Nurse_Vis',
#  'P_FQHC_RHC_Vis',
#  'P_SNF_ADM',
#  'SNF_LOS',
#  'SNF_PayperStay',
#  'N_CAH',
#  'N_FQHC',
#  'N_RHC',
#  'N_ETA',
#  'N_Hosp',
#  'N_Fac_Other',
#  'N_PCP',
#  'N_Spec',
#  'N_NP',
#  'N_PA',
#  'N_CNS',
#  'Perc_Dual',
#  'Perc_CovDiag',
#  'Perc_CovEpisode',
#  'Perc_LTI',
#  'CAHPS_1',
#  'CAHPS_2',
#  'CAHPS_3',
#  'CAHPS_4',
#  'CAHPS_5',
#  'CAHPS_6',
#  'CAHPS_7',
#  'CAHPS_11',
#  'CAHPS_9',
#  'CAHPS_8',
#  'Measure_479',
#  'Measure_484',
#  'QualityID_318',
#  'QualityID_110',
#  'QualityID_226',
#  'QualityID_134_WI',
#  'QualityID_134_eCQM',
#  'QualityID_134_MIPSCQM',
#  'QualityID_113',
#  'QualityID_112',
#  'QualityID_438',
#  'QualityID_370',
#  'QualityID_001_WI',
#  'QualityID_001_eCQM',
#  'QualityID_001_MIPSCQM',
#  'QualityID_236_WI',
#  'QualityID_236_eCQM',
#  'QualityID_236_MIPSCQM']

# %%
ws = wb["Cover"]

# %%
ws["A13"].value
# Out:
# 'A1540, ACO Health Partners, LLC'

# %%
for cell in ws[]:
    print(cell.value)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 for cell in ws[0]:
#       2     print(cell.value)
#
# File ~/.local/lib/python3.12/site-packages/openpyxl/worksheet/worksheet.py:297, in Worksheet.__getitem__(self, key)
#     294 min_col, min_row, max_col, max_row = range_boundaries(key)
#     296 if not any([min_col, min_row, max_col, max_row]):
# --> 297     raise IndexError("{0} is not a valid coordinate or range".format(key))
#     299 if min_row is None:
#     300     cols = tuple(self.iter_cols(min_col, max_col))
#
# IndexError: 0 is not a valid coordinate or range
